# %%
from sys import exit
import time
import random

#this is the Dogstring of the introduction
#The chosen movie is Saw and the instructions of the game are explained next!
print("""

This game is based on the Saw movie


       
         !^                        ...         .JBB?              5###^     .#&&#.     7###.        
         P.   .^!7?J7!~^^::      !. ..        :G####P             5###^     .B&&#.     !###^        
         P. .PBBBBBBB######GY^  .:. . :7     :#######Y.       :   5###^     .B&&#.     !###^        
         7 .G#BBBBBBGGG######G. .!. . ~B.    Y########G:      .   P###^     .B&&#.     !###!        
           :#BBBBBP:   :!7PP!.   :... :#!   Y###########~      .  5###^     .B&&#:     Y###!        
           ^#BBBBBP.             ^. .  P5  ^####G.~###BBB^    !5  5###^     .B&&#:    .####~        
        .7 .P#BBBBBGJ!~.        .?. .. JP .5####!  7##BB#7    ^?  5###^     .B&&#:     P###~        
        .!   ^5GBBBBBB#BGPJ^.   .J. .. 75!######^  ^B#BBBG.   :~  Y###^     .B&&#:    .G###~        
        ..      ~~7YBBBB#####Y.  :.... ~#&&#######B###BBBBP   ^?  Y###^     .G&&#:    .G###~        
             ..     .JBBB#####B?~  ... ^&&#############BBBBJ  ^?  Y###^     .B&&#:     ?###^        
           ^5BBP~     5BB#####&#7. ..  ?&&###GYYJJ?77?5BBBBBY ^J  J###^     :#&&#:     Y###^        
          :##BBBBGYYYPBBB######:   .. ^&&&&#7          .YBBBJ ^?  Y###J     7&&&#^     Y###^        
           JB##BBBBBBBBBB###G?:    .. .YGJ7:             ...      .JB##B55YP###&&#Y77?G###B.        
            .^7Y5555PPGG###B~      ... ^?                           ...::^^^:::~!7??JJJJJ7.         
                        :7YP?.     ... ^P.                                                          
                .                                                                             

Introduction:

You have been kidnapped by a maniac, who's purpose is to get rid of
some population on earth that has had made something wrong in the
society.

There are 3 rounds in the game:

Round 1: Confess or deny.
Round 2: Answer the questions or die.
Round 3: Fight or die.

""")

#this is the function created for "fail" and is used in some parts of the code
#when the players fails or dies

def fail():
    print("You are dead")
    input('Game Over')
    exit(0)

#this function is the start of the game and the player starts the action and feel the emotions of it
#after this function then the round 1 of the game comes

def game_start():
    print("""
    
You woke up the next day in a dark basement, in the middle of nowhere. You
are tied to a chair, and while you are waking up you see a light in the 
distance.
        """)
    
    input("Press enter to try to remove your handcuffs ")
    
    
    print("""
It seems that is impossible to get yourself free... the light is 
getting closer
        """)

    round_1()


#this function is to explain the round 1 the player is doing
#basically is a stage where the player has to confess or deny
#if the player says yes then he/she won't fail and continue to the other stage
#if they say no, Jiksaw will kill the player at once since that's how the movie is
#I called the assasin Jiksaw instead of Jigsaw to not being that similar to the movie

def round_1():
    print("""
With the little strength you have left, you raise your face to look at the killer's face. He ask you:
        
"You remember your name?"
        
        """)

    try:
        name = str(input(f"Yes... my name is "))
    except ValueError:
        print("The name must cointain just letters")

    print(f"{name}, I will ask you a question, and you must be as sincere as possible or there will be consequences")
    
    #with this while what I wanted to do was: if the player says yes then Jiksaw won't cut any finger and the while breaks
    #if the player says no, Jiksaw will cut a finger
    #the loop shows the quantity of fingers left and then the player die
    
    finger = 5
    while finger > 0:
        ans_1 = input(f"Every sinner must redeem his sins in life. Do you know why you are here?\n 1. yes\n 2. no\n")

        if "1" in ans_1:
            print(f"I'm glad you know why you are here. You can call me JikSaw. Lets play a game. It will depend on your next answer if you live or die")
            round_2()
            break
            

        elif "2" in ans_1:
            print("He cuts a finger from your right hand")
            finger -=1
            print(f"You have left {finger} fingers")
            
            
        else:
            print("You didn't answer my question")
            finger -=1
            print(f"You have left {finger} fingers")
        
        print("I'm done with you. Liar")
        fail()

        
#in this round 2 the player will be asked to solve 2 questions
#if they answer correctly the 2 questions then they will play the last round
#but if they don't answer well, then Jiksaw kill them and game over
def round_2():
    
    print("""
I know you are a math professor and the crime you committed. 
If you don't answer these operations properly, there will be consequences
    """)
    
    #list of questions to the player
    op_list = ["Solve this (10 * 15) - 50 / 10 ",
               "What is the square root of 500? "]

    
    operations = 2
    ops_d = [0]*3
    start = time.time() 

    for n in range(len(ops_d)): 

        operation = random.choice(op_list)
        print(operation)
        
        #options of answers of the first quesition CORRECT = 3
        
        if  operation == op_list[0] and operation not in ops_d:
            print("""
            What is the answer?
            1. 65
            2. 15
            3. 10
            """)
            
            
            ans1 = input(" ")
            
            #output when the player answers correctly
            if ans1 == "3":
                print("Correct! At least you are good at something.")
                operations -=1
                ops_d[n] = operation
                print(f" Math games left {operations}")
                
            
            else:
                print("I thought you knew the answer... \
                was your last chance to survive.")
                fail()
            
        #option of answers for the second question
        if operation == op_list[1] and operation not in ops_d:
            print("""
            1. 22.70
            2. 22.36
            3. 23.30
            """)
            
            
            ans2 = input(" ")
            
            if ans2 == "2":
                print("Uhh.. you want to survive ah? That's correct Professor.")
                operations -=1
                ops_d[n] = operation
                print(f" Math games left {operations}")
                
            else:
                print("Nope... WRONG answerrr... bye bye professor!")
                fail()
    end = time.time()
    print(f"You took {format(end-start)} seconds")           
        
    round_3()
    
#for this last round, the player will know why is guilty
#there are 2 options the player can choose

def round_3():
    
    print(f"""
Jiksaw says - "Well... well... you managed to solve all my questions. 
But that doesn't mean you're safe, it's only just beginning.
you have sinned, I'm gonna refresh your memory"
""")

    print("""

The Jiksaw comes and sits in front of you with the newspaper in hands.

He points to an ad, that says...""")

    print("""

NEWSPAPER FIRST PAGE

"In the early hours of Sunday morning, an drunk person ran over a vehicle with
3 other people, fleeing the scene and leaving the victims without vital signs." 

""")

    print("Then Jiksaw start talking") 
    print("""

"This is you professor... a coward who was unable to take responsibility for his actions. 
This world does not need more people like you or me, but at this point, it won't be me who judges, 
it will be you.""")

    print("""JikSaw hits you, leaving you slightly unconscious on the floor....

He uncuffs you, leaves a knife on the table and pulls out a gun.

You are about to take action""")

#the 2 options
    print("""
You have 2 options
1. Take the knife and fight with him
2. Let him does whatever he wants with you
    """)
    
    ans3 = input(" ")

    #conditionals that decide what is the end of the game
    if ans3 == "1":   
        print("""
        
You take action by grabbing the knife with the strength you have left.
You swing at him stabbing him in his neck BUT .... he manages to shoot you.       
        """)
        
        print("""
5 minutes after...
        
You get out of where you are trapped... you are bleeding from the wound.
        
And a few seconds after your death, the only word that comes to your mind is "Sorry".
        
        """)
        fail()
    
    elif ans3 == "2":
        print("""
So sorry for you... you committed a crime, you deserve to die!

Jigsaw shoots you in the head
        """)
        fail()
              

    
game_start()
# Out:
# This game is based on the Saw movie
#
#
#
#          !^                        ...         .JBB?              5###^     .#&&#.     7###.
#          P.   .^!7?J7!~^^::      !. ..        :G####P             5###^     .B&&#.     !###^
#          P. .PBBBBBBB######GY^  .:. . :7     :#######Y.       :   5###^     .B&&#.     !###^
#          7 .G#BBBBBBGGG######G. .!. . ~B.    Y########G:      .   P###^     .B&&#.     !###!
#            :#BBBBBP:   :!7PP!.   :... :#!   Y###########~      .  5###^     .B&&#:     Y###!
#            ^#BBBBBP.             ^. .  P5  ^####G.~###BBB^    !5  5###^     .B&&#:    .####~
#         .7 .P#BBBBBGJ!~.        .?. .. JP .5####!  7##BB#7    ^?  5###^     .B&&#:     P###~
#         .!   ^5GBBBBBB#BGPJ^.   .J. .. 75!######^  ^B#BBBG.   :~  Y###^     .B&&#:    .G###~
#         ..      ~~7YBBBB#####Y.  :.... ~#&&#######B###BBBBP   ^?  Y###^     .G&&#:    .G###~
#              ..     .JBBB#####B?~  ... ^&&#############BBBBJ  ^?  Y###^     .B&&#:     ?###^
# ...
